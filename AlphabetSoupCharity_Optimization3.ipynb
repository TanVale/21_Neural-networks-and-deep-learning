# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
application_df['ASK_AMT'].value_counts()
# Out:
# ASK_AMT
# 5000        25398
# 10478           3
# 15583           3
# 63981           3
# 6725            3
#             ...
# 5371754         1
# 30060           1
# 43091152        1
# 18683           1
# 36500179        1
# Name: count, Length: 8747, dtype: int64

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
# Additionally drop: 'STATUS', 'SPECIAL_CONSIDERATIONS'
to_drop = ['EIN','STATUS', 'SPECIAL_CONSIDERATIONS']
application_df.drop(to_drop, inplace=True, axis=1)
application_df.head(2)
# Out:
#                                      NAME APPLICATION_TYPE  AFFILIATION  \
# 0            BLUE KNIGHTS MOTORCYCLE CLUB              T10  Independent
# 1  AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3  Independent
#
#   CLASSIFICATION      USE_CASE  ORGANIZATION INCOME_AMT  ASK_AMT  \
# 0          C1000    ProductDev   Association          0     5000
# 1          C2000  Preservation  Co-operative     1-9999   108590
#
#    IS_SUCCESSFUL
# 0              1
# 1              1

# %%
name_count = application_df["NAME"].value_counts()
names_to_replace = list(name_count [name_count<6].index)

# Replace in dataframe
for name in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(name,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# NAME
# Other                                           20043
# PARENT BOOSTER USA INC                           1260
# TOPS CLUB INC                                     765
# UNITED STATES BOWLING CONGRESS INC                700
# WASHINGTON STATE UNIVERSITY                       492
#                                                 ...
# HABITAT FOR HUMANITY INTERNATIONAL                  6
# DAMAGE PREVENTION COUNCIL OF TEXAS                  6
# FLEET RESERVE ASSOCIATION                           6
# HUGH OBRIAN YOUTH LEADERSHIP                        6
# INTERNATIONAL CONGRESS OF CHURCHES MINISTERS        6
# Name: count, Length: 355, dtype: int64

# %%
# Replace all application types with count below 100
application_types_to_replace = ["T13", "T12", "T2", "T25", "T14", "T29", "T15", "T17", "T9"]

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# APPLICATION_TYPE
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: count, dtype: int64

# %%
# Get all CLASSIFICATION values with count below 1000
filt_df = application_df.groupby("CLASSIFICATION").filter(lambda classification: len(classification) < 400)
classifications_to_replace = filt_df["CLASSIFICATION"].unique()

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# CLASSIFICATION
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Other     1484
# C7000      777
# Name: count, dtype: int64

# %%
application_df['INCOME_AMT'].value_counts()
# Out:
# INCOME_AMT
# 0                24388
# 25000-99999       3747
# 100000-499999     3374
# 1M-5M              955
# 1-9999             728
# 10000-24999        543
# 10M-50M            240
# 5M-10M             185
# 50M+               139
# Name: count, dtype: int64

# %%
# # Get all large INCOME_AMT
# amts_to_replace = ['10M-50M', '5M-10M', '50M+']

# # Replace in dataframe
# for cls in amts_to_replace:
#     application_df['INCOME_AMT'] = application_df['INCOME_AMT'].replace(cls,"5M+")

# # Check to make sure binning was successful
# application_df['INCOME_AMT'].value_counts()

# %%
# Convert categorical data to numeric with `pd.get_dummies`
with_dummies = pd.get_dummies(application_df)
with_dummies.head(2)
# Out:
#    ASK_AMT  IS_SUCCESSFUL  NAME_AACE INTERNATIONAL  \
# 0     5000              1                    False
# 1   108590              1                    False
#
#    NAME_ACE MENTOR PROGRAM OF AMERICA INC  \
# 0                                   False
# 1                                   False
#
#    NAME_AFRICAN-AMERICAN POSTAL LEAGUE UNITED FOR SUCCESS A-PLUS  \
# 0                                              False
# 1                                              False
#
#    NAME_AIR FORCE ASSOCIATION  NAME_ALABAMA FEDERATION OF WOMENS CLUBS  \
# 0                       False                                    False
# 1                       False                                    False
#
#    NAME_ALABAMA TREASURE FOREST ASSOCIATION  \
# 0                                     False
# 1                                     False
#
#    NAME_ALBANY STATE UNIVERSITY NATIONAL ALUMNI ASSOCIATION  \
# 0                                              False
# 1                                              False
#
#    NAME_ALPHA PHI OMEGA  ...  ORGANIZATION_Trust  INCOME_AMT_0  \
# 0                 False  ...               False          True
# 1                 False  ...               False         False
#
#    INCOME_AMT_1-9999  INCOME_AMT_10000-24999  INCOME_AMT_100000-499999  \
# 0              False                   False                     False
# 1               True                   False                     False
#
#    INCOME_AMT_10M-50M  INCOME_AMT_1M-5M  INCOME_AMT_25000-99999  \
# 0               False             False                   False
# 1               False             False                   False
#
#    INCOME_AMT_50M+  INCOME_AMT_5M-10M
# 0            False              False
# 1            False              False
#
# [2 rows x 397 columns]

# %%
# Split our preprocessed data into our features and target arrays
X = with_dummies.drop(["IS_SUCCESSFUL"], axis=1).values
y = with_dummies["IS_SUCCESSFUL"].values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
input_features_num = len(X_train[0])
layer1_nodes = 60
layer2_nodes = 30

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=layer1_nodes, input_dim=input_features_num, activation="relu"))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=layer2_nodes, activation="sigmoid"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=layer2_nodes, activation="sigmoid"))

# Output layer; sigmoid chosen due to binary nature of target
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 60)                23820
#
#  dense_1 (Dense)             (None, 30)                1830
#
#  dense_2 (Dense)             (None, 30)                930
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 26611 (103.95 KB)
# Trainable params: 26611 (103.95 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer='adam', metrics=["accuracy"])

# %%
fit_model = nn.fit(X_train_scaled,y_train,epochs=125)
# Out:
# Epoch 1/125
# 804/804 [==============================] - 4s 3ms/step - loss: 0.4972 - accuracy: 0.7670
# Epoch 2/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4372 - accuracy: 0.7929
# Epoch 3/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4309 - accuracy: 0.7948
# Epoch 4/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4280 - accuracy: 0.7957
# Epoch 5/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4261 - accuracy: 0.7942
# Epoch 6/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4242 - accuracy: 0.7981
# Epoch 7/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4237 - accuracy: 0.7966
# Epoch 8/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4228 - accuracy: 0.7963
# Epoch 9/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4218 - accuracy: 0.7972
# Epoch 10/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4212 - accuracy: 0.7976
# Epoch 11/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4203 - accuracy: 0.7979
# Epoch 12/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4201 - accuracy: 0.7989
# Epoch 13/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4188 - accuracy: 0.7991
# Epoch 14/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4190 - accuracy: 0.7983
# Epoch 15/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4176 - accuracy: 0.7987
# Epoch 16/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4168 - accuracy: 0.7993
# Epoch 17/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4166 - accuracy: 0.7995
# Epoch 18/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4157 - accuracy: 0.8017
# Epoch 19/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4155 - accuracy: 0.7987
# Epoch 20/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4147 - accuracy: 0.8014
# Epoch 21/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4144 - accuracy: 0.8008
# Epoch 22/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4139 - accuracy: 0.8007
# Epoch 23/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4135 - accuracy: 0.8010
# Epoch 24/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4133 - accuracy: 0.8009
# Epoch 25/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4125 - accuracy: 0.8016
# Epoch 26/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4123 - accuracy: 0.8006
# Epoch 27/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4121 - accuracy: 0.8011
# Epoch 28/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4114 - accuracy: 0.8020
# Epoch 29/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4112 - accuracy: 0.8021
# Epoch 30/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4109 - accuracy: 0.8028
# Epoch 31/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4104 - accuracy: 0.8014
# Epoch 32/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4100 - accuracy: 0.8022
# Epoch 33/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4101 - accuracy: 0.8010
# Epoch 34/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4101 - accuracy: 0.8022
# Epoch 35/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4093 - accuracy: 0.8036
# Epoch 36/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4091 - accuracy: 0.8020
# Epoch 37/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4093 - accuracy: 0.8028
# Epoch 38/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4086 - accuracy: 0.8029
# Epoch 39/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4088 - accuracy: 0.8036
# Epoch 40/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4083 - accuracy: 0.8048
# Epoch 41/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4080 - accuracy: 0.8034
# Epoch 42/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4077 - accuracy: 0.8049
# Epoch 43/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4076 - accuracy: 0.8043
# Epoch 44/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4077 - accuracy: 0.8042
# Epoch 45/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4072 - accuracy: 0.8033
# Epoch 46/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4067 - accuracy: 0.8041
# Epoch 47/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4069 - accuracy: 0.8051
# Epoch 48/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4068 - accuracy: 0.8040
# Epoch 49/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4062 - accuracy: 0.8047
# Epoch 50/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4063 - accuracy: 0.8030
# Epoch 51/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4062 - accuracy: 0.8045
# Epoch 52/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4060 - accuracy: 0.8045
# Epoch 53/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4056 - accuracy: 0.8046
# Epoch 54/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4054 - accuracy: 0.8043
# Epoch 55/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4054 - accuracy: 0.8039
# Epoch 56/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4055 - accuracy: 0.8051
# Epoch 57/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4052 - accuracy: 0.8048
# Epoch 58/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4047 - accuracy: 0.8048
# Epoch 59/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4045 - accuracy: 0.8052
# Epoch 60/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4040 - accuracy: 0.8054
# Epoch 61/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4044 - accuracy: 0.8061
# Epoch 62/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4044 - accuracy: 0.8046
# Epoch 63/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4040 - accuracy: 0.8046
# Epoch 64/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4038 - accuracy: 0.8059
# Epoch 65/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4039 - accuracy: 0.8052
# Epoch 66/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4037 - accuracy: 0.8055
# Epoch 67/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4037 - accuracy: 0.8064
# Epoch 68/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4036 - accuracy: 0.8048
# Epoch 69/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4033 - accuracy: 0.8055
# Epoch 70/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4029 - accuracy: 0.8059
# Epoch 71/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4034 - accuracy: 0.8059
# Epoch 72/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4027 - accuracy: 0.8056
# Epoch 73/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4029 - accuracy: 0.8062
# Epoch 74/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4028 - accuracy: 0.8061
# Epoch 75/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4026 - accuracy: 0.8054
# Epoch 76/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4023 - accuracy: 0.8052
# Epoch 77/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4022 - accuracy: 0.8052
# Epoch 78/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4024 - accuracy: 0.8055
# Epoch 79/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4021 - accuracy: 0.8057
# Epoch 80/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4019 - accuracy: 0.8055
# Epoch 81/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4021 - accuracy: 0.8059
# Epoch 82/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4016 - accuracy: 0.8058
# Epoch 83/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4017 - accuracy: 0.8068
# Epoch 84/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4014 - accuracy: 0.8069
# Epoch 85/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4015 - accuracy: 0.8059
# Epoch 86/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4017 - accuracy: 0.8065
# Epoch 87/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4019 - accuracy: 0.8061
# Epoch 88/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4017 - accuracy: 0.8065
# Epoch 89/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4013 - accuracy: 0.8066
# Epoch 90/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4014 - accuracy: 0.8061
# Epoch 91/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4012 - accuracy: 0.8066
# Epoch 92/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4012 - accuracy: 0.8068
# Epoch 93/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8066
# Epoch 94/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4011 - accuracy: 0.8070
# Epoch 95/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4009 - accuracy: 0.8065
# Epoch 96/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4014 - accuracy: 0.8069
# Epoch 97/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4009 - accuracy: 0.8068
# Epoch 98/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4013 - accuracy: 0.8063
# Epoch 99/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4009 - accuracy: 0.8075
# Epoch 100/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4004 - accuracy: 0.8066
# Epoch 101/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4008 - accuracy: 0.8067
# Epoch 102/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4003 - accuracy: 0.8072
# Epoch 103/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4005 - accuracy: 0.8070
# Epoch 104/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4006 - accuracy: 0.8064
# Epoch 105/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4004 - accuracy: 0.8074
# Epoch 106/125
# 804/804 [==============================] - 5s 6ms/step - loss: 0.4005 - accuracy: 0.8069
# Epoch 107/125
# 804/804 [==============================] - 5s 6ms/step - loss: 0.4007 - accuracy: 0.8069
# Epoch 108/125
# 804/804 [==============================] - 5s 6ms/step - loss: 0.4005 - accuracy: 0.8073
# Epoch 109/125
# 804/804 [==============================] - 6s 8ms/step - loss: 0.4004 - accuracy: 0.8070
# Epoch 110/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4004 - accuracy: 0.8076
# Epoch 111/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4003 - accuracy: 0.8067
# Epoch 112/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4002 - accuracy: 0.8070
# Epoch 113/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4006 - accuracy: 0.8078
# Epoch 114/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4005 - accuracy: 0.8080
# Epoch 115/125
# 804/804 [==============================] - 3s 4ms/step - loss: 0.4004 - accuracy: 0.8077
# Epoch 116/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4005 - accuracy: 0.8078
# Epoch 117/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4003 - accuracy: 0.8073
# Epoch 118/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.3999 - accuracy: 0.8072
# Epoch 119/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.3997 - accuracy: 0.8070
# Epoch 120/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.4002 - accuracy: 0.8066
# Epoch 121/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.4002 - accuracy: 0.8068
# Epoch 122/125
# 804/804 [==============================] - 3s 3ms/step - loss: 0.3998 - accuracy: 0.8082
# Epoch 123/125
# 804/804 [==============================] - 2s 3ms/step - loss: 0.4000 - accuracy: 0.8076
# Epoch 124/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.3999 - accuracy: 0.8075
# Epoch 125/125
# 804/804 [==============================] - 2s 2ms/step - loss: 0.3999 - accuracy: 0.8072

# %%
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose = 2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - loss: 0.4627 - accuracy: 0.7936 - 533ms/epoch - 2ms/step
# Loss: 0.4626712501049042, Accuracy: 0.793586015701294

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# AlphabetSoupcharity_Optimization3.h5  drive  sample_data

# %%
# !pwd
# Out:
# /content

# %%
nn.save("/content/drive/MyDrive/AlphabetSoupcharity_Optimization3.h5")
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
